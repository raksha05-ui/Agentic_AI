# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Verify API key is set (required for ChatGoogleGenerativeAI)
if not os.getenv("GOOGLE_API_KEY"):
    print("⚠️  WARNING: GOOGLE_API_KEY not set in environment.")
    print("Please create a .env file or set GOOGLE_API_KEY environment variable.")
    print("Get your key from: https://aistudio.google.com/app/apikey")

# %%
# !pip install langchain_google_genai
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.2/74.2 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 14.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.5.5
#     Uninstalling langchain-core-1.5.5:
#       Successfully uninstalled langchain-core-1.5.5
# ...
# False

# %%
import os
llm=ChatGoogleGenerativeAI(model="gemini-3.6-flash", api_key=os.getenv("GOOGLE_API_KEY"))

# %%
with open("blood_work.txt") as f:
    blood_work = f.read()
print(blood_work)
# Out:
# BLOOD WORK REPORT
# Sample Patient: Mr. Arjun Sharma
# Age/Sex: 29 years / Male
# Location: Delhi, India
# Sample Date: 22-Aug-2026
#
# COMPLETE BLOOD COUNT (CBC)
# Hemoglobin: 14.2 g/dL
# RBC Count: 4.85 million/µL
# WBC Count: 7,200 cells/µL
# Platelet Count: 2.65 lakh/µL
# Hematocrit (PCV): 43.1 %
# MCV: 88.9 fL
# MCH: 29.3 pg
# MCHC: 33.0 g/dL
# RDW: 13.2 %
#
# DIFFERENTIAL LEUKOCYTE COUNT
# Neutrophils: 58 %
# Lymphocytes: 34 %
# Monocytes: 5 %
# Eosinophils: 3 %
# Basophils: 0 %
#
# BLOOD CHEMISTRY
# Fasting Blood Glucose: 92 mg/dL
# HbA1c: 5.3 %
# Total Cholesterol: 178 mg/dL
# HDL Cholesterol: 48 mg/dL
# LDL Cholesterol: 108 mg/dL
# Triglycerides: 112 mg/dL
#
# LIVER FUNCTION
# Total Bilirubin: 0.8 mg/dL
# AST (SGOT): 24 U/L
# ALT (SGPT): 27 U/L
# Alkaline Phosphatase: 82 U/L
# Total Protein: 7.1 g/dL
# Albumin: 4.5 g/dL
#
# KIDNEY FUNCTION
# Blood Urea: 26 mg/dL
# Serum Creatinine: 0.9 mg/dL
# Uric Acid: 5.4 mg/dL
#
# ...

# %%
res=llm.invoke(f"""You are a medical data extraction model, from this medical report extract all test values and classify them as high,low or normal format your response as: Test_name:, Status:,Refernce:, blood_report:{blood_work} """)

# %%
print(res)
# Out:
# content=[{'type': 'text', 'text': 'Here is the extracted medical data with test classifications based on standard adult male reference ranges:\n\nTest_name: Hemoglobin (14.2 g/dL), Status: Normal, Reference: 13.8 - 17.2 g/dL\nTest_name: RBC Count (4.85 million/µL), Status: Normal, Reference: 4.5 - 5.9 million/µL\nTest_name: WBC Count (7,200 cells/µL), Status: Normal, Reference: 4,500 - 11,000 cells/µL\nTest_name: Platelet Count (2.65 lakh/µL), Status: Normal, Reference: 1.5 - 4.5 lakh/µL\nTest_name: Hematocrit (PCV) (43.1 %), Status: Normal, Reference: 40.7 - 50.3 %\nTest_name: MCV (88.9 fL), Status: Normal, Reference: 80 - 100 fL\nTest_name: MCH (29.3 pg), Status: Normal, Reference: 27 - 33 pg\nTest_name: MCHC (33.0 g/dL), Status: Normal, Reference: 32 - 36 g/dL\nTest_name: RDW (13.2 %), Status: Normal, Reference: 11.5 - 14.5 %\nTest_name: Neutrophils (58 %), Status: Normal, Reference: 40 - 70 %\nTest_name: Lymphocytes (34 %), Status: Normal, Reference: 20 - 40 %\nTest_name: Monocyt
# ...

# %%
diet_prompt=(f"""you are a dietician so give the short health summary in some lines explaining the patients health in simple langauage,also a short indian diet plan with two sections only 1) foot to avoid,2)food to eat more""")

# %%
llm=ChatGoogleGenerativeAI(model="gemini-2.0-flash", api_key=os.getenv("GOOGLE_API_KEY"))
# Out:
# content=[{'type': 'text', 'text': '### **Health Summary**\nBased on your health assessment, your body is currently experiencing low energy levels and slow digestion, likely due to an imbalance in daily nutrients and high intake of refined carbohydrates. To improve your overall stamina, manage weight, and boost your metabolism, your body needs a shift toward high-fiber, protein-rich, and home-cooked foods along with proper daily hydration.\n\n---\n\n### **Short Indian Diet Plan**\n\n#### **1) Foods to Avoid**\n*   **Deep-Fried Snacks:** Samosas, pakoras, puris, and packaged *namkeen* or chips.\n*   **Refined Flour (Maida):** White bread, naan, bhature, biscuits, and bakery items.\n*   **Sugary Drinks & Sweets:** Packaged juices, sodas, traditional *mithai*, and chai/coffee with extra sugar.\n*   **Excessive Fats & Heavy Gravies:** Restaurant-style butter-loaded curries and excessive ghee in cooking.\n\n#### **2) Foods to Eat More**\n*   **Whole Grains & Millets:** Multigrain or *jowar
# ...
